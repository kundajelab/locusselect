# %%
# %%bash
# for idx in 0 1 2 3 4 5; do
#     bedfile="../coordinates/coordinates_"$idx".bed"
#     cat $bedfile | perl -lane 'print $F[0]."\t".($F[1]+$F[9]-500)."\t".($F[1]+$F[9]+500)' > expanded_coordinates_$idx.bed
#     bedtools getfasta -fi /mnt/data/annotations/by_release/hg19/male.hg19.fa -bed expanded_coordinates_$idx.bed > expanded_coordinates_$idx.fa
# done

# %%
indices = [0,1,2,3,4,5]
fastafiles = ["expanded_coordinates_"+str(idx)+".fa" for idx in indices]
model_hdf5 = "DNASE.K562.regressionlabels.allbins.0"

# %%
# !md5sum DNASE.K562.regressionlabels.allbins.0
# Out:
# f46d83d699aea9428efe1535731eb81b  DNASE.K562.regressionlabels.allbins.0

# %%
from keras.models import load_model
import tensorflow as tf
from keras import backend as K

def ambig_binary_crossentropy(y_true,y_pred):
    nonAmbig=tf.math.logical_not(tf.is_nan(y_true))
    return K.mean(K.binary_crossentropy(tf.boolean_mask(y_true,nonAmbig), tf.boolean_mask(y_pred,nonAmbig)), axis=-1);

def dummy_metric(y,z):
    return tf.reduce_mean(y)

loaded_model = load_model(model_hdf5,
                          custom_objects={
                            'ambig_mean_squared_error': ambig_binary_crossentropy,
                            'sensitivity': dummy_metric,
                            'specificity': dummy_metric,
                            'precision': dummy_metric,
                            'recall': dummy_metric,
                            'fpr': dummy_metric,
                            'fnr': dummy_metric,
                            'tnr': dummy_metric,
                            'f1': dummy_metric,
                            'tpr': dummy_metric})
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0709 17:17:23.896869 140616266041088 deprecation_wrapper.py:119] From /users/avanti/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0709 17:17:23.940327 140616266041088 deprecation_wrapper.py:119] From /users/avanti/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0709 17:17:23.980336 140616266041088 deprecation_wrapper.py:119] From /users/avanti/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0709 17:17:23.981257 140616266041088 deprecation_wrapper.py:119] From /users/avanti/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0709 17:17:23.982156 140616266041088 deprecation_wrapper.py:119] From /users/avanti/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:184: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0709 17:17:27.533316 140616266041088 deprecation_wrapper.py:119] From /users/avanti/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0709 17:17:27.610494 140616266041088 deprecation_wrapper.py:119] From /users/avanti/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0709 17:17:27.994118 140616266041088 deprecation.py:506] From /users/avanti/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0709 17:17:28.492673 140616266041088 deprecation_wrapper.py:119] From /users/avanti/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0709 17:17:28.521754 140616266041088 deprecation.py:323] From /users/avanti/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
import numpy as np

#this is set up for 1d convolutions where examples
#have dimensions (len, num_channels)
#the channel axis is the axis for one-hot encoding.
def one_hot_encode_along_channel_axis(sequence):
    to_return = np.zeros((len(sequence),4), dtype=np.int8)
    seq_to_one_hot_fill_in_array(zeros_array=to_return,
                                 sequence=sequence, one_hot_axis=1)
    return to_return

def seq_to_one_hot_fill_in_array(zeros_array, sequence, one_hot_axis):
    assert one_hot_axis==0 or one_hot_axis==1
    if (one_hot_axis==0):
        assert zeros_array.shape[1] == len(sequence)
    elif (one_hot_axis==1): 
        assert zeros_array.shape[0] == len(sequence)
    #will mutate zeros_array
    for (i,char) in enumerate(sequence):
        if (char=="A" or char=="a"):
            char_idx = 0
        elif (char=="C" or char=="c"):
            char_idx = 1
        elif (char=="G" or char=="g"):
            char_idx = 2
        elif (char=="T" or char=="t"):
            char_idx = 3
        elif (char=="N" or char=="n"):
            continue #leave that pos as all 0's
        else:
            raise RuntimeError("Unsupported character: "+str(char))
        if (one_hot_axis==0):
            zeros_array[char_idx,i] = 1
        elif (one_hot_axis==1):
            zeros_array[i,char_idx] = 1

sequences_sets = [[x[1].rstrip() for x in enumerate(open(fastafile)) if x[0]%2==1]
                  for fastafile in fastafiles]
onehot_func = lambda x: np.array([one_hot_encode_along_channel_axis(seq)[None,:,:] for seq in x])
onehot_sets = [onehot_func(x).squeeze() for x in sequences_sets]

# %%
# %reload_ext autoreload
# %autoreload 2
import locusselect
import importlib
from locusselect.ism import in_silico_mutagenesis

for idx,(sequences,onehot) in list(enumerate(zip(sequences_sets, onehot_sets)))[1:]:
    onehot = onehot[:,None,:,:]
    ism_scores = in_silico_mutagenesis(model=loaded_model,
                                       X=onehot, task_index=0, target_layer_idx=-1,
                                       start_pos=375, end_pos=625)
    ism_scores = np.squeeze(ism_scores)
    np.save("ismscores_"+str(idx)+".npy", ism_scores)
# Out:
# ISM: task:0 sample:0
# ISM: task:0 sample:1
# ISM: task:0 sample:2
# ISM: task:0 sample:3
# ISM: task:0 sample:4
# ISM: task:0 sample:5
# ISM: task:0 sample:6
# ISM: task:0 sample:7
# ISM: task:0 sample:8
# ISM: task:0 sample:9
# ISM: task:0 sample:10
# ISM: task:0 sample:11
# ISM: task:0 sample:12
# ISM: task:0 sample:13
# ISM: task:0 sample:14
# ISM: task:0 sample:15
# ISM: task:0 sample:16
# ISM: task:0 sample:17
# ISM: task:0 sample:18
# ISM: task:0 sample:19
# ISM: task:0 sample:20
# ISM: task:0 sample:21
# ISM: task:0 sample:22
# ISM: task:0 sample:23
# ISM: task:0 sample:24
# ISM: task:0 sample:25
# ISM: task:0 sample:26
# ISM: task:0 sample:27
# ISM: task:0 sample:28
# ISM: task:0 sample:29
# ISM: task:0 sample:30
# ISM: task:0 sample:31
# ISM: task:0 sample:32
# ISM: task:0 sample:33
# ISM: task:0 sample:34
# ISM: task:0 sample:35
# ISM: task:0 sample:36
# ISM: task:0 sample:37
# ISM: task:0 sample:38
# ISM: task:0 sample:39
# ISM: task:0 sample:40
# ISM: task:0 sample:41
# ISM: task:0 sample:42
# ISM: task:0 sample:43
# ISM: task:0 sample:44
# ISM: task:0 sample:45
# ISM: task:0 sample:46
# ISM: task:0 sample:47
# ISM: task:0 sample:48
# ISM: task:0 sample:49
# ISM: task:0 sample:50
# ISM: task:0 sample:51
# ISM: task:0 sample:52
# ISM: task:0 sample:53
# ISM: task:0 sample:54
# ISM: task:0 sample:55
# ISM: task:0 sample:56
# ISM: task:0 sample:57
# ISM: task:0 sample:58
# ISM: task:0 sample:59
# ISM: task:0 sample:60
# ISM: task:0 sample:61
# ISM: task:0 sample:62
# ISM: task:0 sample:63
# ISM: task:0 sample:64
# ISM: task:0 sample:65
# ISM: task:0 sample:66
# ISM: task:0 sample:67
# ISM: task:0 sample:68
# ISM: task:0 sample:69
# ISM: task:0 sample:70
# ISM: task:0 sample:71
# ISM: task:0 sample:72
# ISM: task:0 sample:73
# ISM: task:0 sample:74
# ISM: task:0 sample:75
# ISM: task:0 sample:76
# ISM: task:0 sample:77
# ISM: task:0 sample:78
# ISM: task:0 sample:79
# ISM: task:0 sample:80
# ISM: task:0 sample:81
# ISM: task:0 sample:82
# ISM: task:0 sample:83
# ISM: task:0 sample:84
# ISM: task:0 sample:85
# ISM: task:0 sample:86
# ISM: task:0 sample:87
# ISM: task:0 sample:88
# ISM: task:0 sample:89
# ISM: task:0 sample:90
# ISM: task:0 sample:91
# ISM: task:0 sample:92
# ISM: task:0 sample:93
# ISM: task:0 sample:94
# ISM: task:0 sample:95
# ISM: task:0 sample:96
# ISM: task:0 sample:97
# ISM: task:0 sample:98
# ISM: task:0 sample:99
# ISM: task:0 sample:100
# ISM: task:0 sample:101
# ISM: task:0 sample:102
# ISM: task:0 sample:103
# ISM: task:0 sample:104
# ISM: task:0 sample:105
# ISM: task:0 sample:106
# ISM: task:0 sample:107
# ISM: task:0 sample:108
# ISM: task:0 sample:109
# ISM: task:0 sample:110
# ISM: task:0 sample:111
# ISM: task:0 sample:112
# ISM: task:0 sample:113
# ISM: task:0 sample:114
# ISM: task:0 sample:115
# ISM: task:0 sample:116
# ISM: task:0 sample:117
# ISM: task:0 sample:118
# ISM: task:0 sample:119
# ISM: task:0 sample:120
# ISM: task:0 sample:121
# ISM: task:0 sample:122
# ISM: task:0 sample:123
# ISM: task:0 sample:124
# ISM: task:0 sample:125
# ISM: task:0 sample:126
# ISM: task:0 sample:127
# ISM: task:0 sample:128
# ISM: task:0 sample:129
# ISM: task:0 sample:130
# ISM: task:0 sample:131
# ISM: task:0 sample:132
# ISM: task:0 sample:133
# ISM: task:0 sample:134
# ISM: task:0 sample:135
# ISM: task:0 sample:136
# ISM: task:0 sample:137
# ISM: task:0 sample:138
# ISM: task:0 sample:139
# ISM: task:0 sample:140
# ISM: task:0 sample:141
# ISM: task:0 sample:142
# ISM: task:0 sample:143
# ISM: task:0 sample:144
# ISM: task:0 sample:145
# ISM: task:0 sample:146
# ISM: task:0 sample:147
# ISM: task:0 sample:148
# ISM: task:0 sample:149
# ISM: task:0 sample:150
# ISM: task:0 sample:151
# ISM: task:0 sample:152
# ISM: task:0 sample:153
# ISM: task:0 sample:154
# ISM: task:0 sample:155
# ISM: task:0 sample:156
# ISM: task:0 sample:157
# ISM: task:0 sample:158
# ISM: task:0 sample:159
# ISM: task:0 sample:160
# ISM: task:0 sample:161
# ISM: task:0 sample:162
# ISM: task:0 sample:163
# ISM: task:0 sample:164
# ISM: task:0 sample:165
# ISM: task:0 sample:166
# ISM: task:0 sample:167
# ISM: task:0 sample:168
# ISM: task:0 sample:169
# ISM: task:0 sample:170
# ISM: task:0 sample:171
# ISM: task:0 sample:172
# ISM: task:0 sample:173
# ISM: task:0 sample:174
# ISM: task:0 sample:175
# ISM: task:0 sample:176
# ISM: task:0 sample:177
# ISM: task:0 sample:178
# ISM: task:0 sample:179
# ISM: task:0 sample:180
# ISM: task:0 sample:181
# ISM: task:0 sample:182
# ISM: task:0 sample:183
# ISM: task:0 sample:184
# ISM: task:0 sample:185
# ISM: task:0 sample:186
# ISM: task:0 sample:187
# ISM: task:0 sample:188
# ISM: task:0 sample:189
# ISM: task:0 sample:190
# ISM: task:0 sample:191
# ISM: task:0 sample:192
# ISM: task:0 sample:193
# ISM: task:0 sample:194
# ISM: task:0 sample:195
# ISM: task:0 sample:196
# ISM: task:0 sample:197
# ISM: task:0 sample:198
# ISM: task:0 sample:199
# ISM: task:0 sample:200
# ISM: task:0 sample:201
# ISM: task:0 sample:202
# ISM: task:0 sample:203
# ISM: task:0 sample:204
# ISM: task:0 sample:205
# ISM: task:0 sample:206
# ISM: task:0 sample:207
# ISM: task:0 sample:208
# ISM: task:0 sample:209
# ISM: task:0 sample:210
# ISM: task:0 sample:211
# ISM: task:0 sample:212
# ISM: task:0 sample:213
# ISM: task:0 sample:214
# ISM: task:0 sample:215
# ISM: task:0 sample:216
# ISM: task:0 sample:217
# ISM: task:0 sample:218
# ISM: task:0 sample:219
# ISM: task:0 sample:220
# ISM: task:0 sample:221
# ISM: task:0 sample:222
# ISM: task:0 sample:223
# ISM: task:0 sample:224
# ISM: task:0 sample:225
# ISM: task:0 sample:226
# ISM: task:0 sample:227
# ISM: task:0 sample:228
# ISM: task:0 sample:229
# ISM: task:0 sample:230
# ISM: task:0 sample:231
# ISM: task:0 sample:232
# ISM: task:0 sample:233
# ISM: task:0 sample:234
# ISM: task:0 sample:235
# ISM: task:0 sample:236
# ISM: task:0 sample:237
# ISM: task:0 sample:238
# ISM: task:0 sample:239
# ISM: task:0 sample:240
# ISM: task:0 sample:241
# ISM: task:0 sample:242
# ISM: task:0 sample:243
# ISM: task:0 sample:244
# ISM: task:0 sample:245
# ISM: task:0 sample:246
# ISM: task:0 sample:247
# ISM: task:0 sample:248
# ISM: task:0 sample:249
# ISM: task:0 sample:250
# ISM: task:0 sample:251
# ISM: task:0 sample:252
# ISM: task:0 sample:253
# ISM: task:0 sample:254
# ISM: task:0 sample:255
# ISM: task:0 sample:256
# ISM: task:0 sample:257
# ISM: task:0 sample:258
# ISM: task:0 sample:259
# ISM: task:0 sample:260
# ISM: task:0 sample:261
# ISM: task:0 sample:262
# ISM: task:0 sample:263
# ISM: task:0 sample:264
# ISM: task:0 sample:265
# ISM: task:0 sample:266
# ISM: task:0 sample:267
# ISM: task:0 sample:268
# ISM: task:0 sample:269
# ISM: task:0 sample:270
# ISM: task:0 sample:271
# ISM: task:0 sample:272
# ISM: task:0 sample:273
# ISM: task:0 sample:274
# ISM: task:0 sample:275
# ISM: task:0 sample:276
# ISM: task:0 sample:277
# ISM: task:0 sample:278
# ISM: task:0 sample:279
# ISM: task:0 sample:280
# ISM: task:0 sample:281
# ISM: task:0 sample:282
# ISM: task:0 sample:283
# ISM: task:0 sample:284
# ISM: task:0 sample:285
# ISM: task:0 sample:286
# ISM: task:0 sample:287
# ISM: task:0 sample:288
# ISM: task:0 sample:289
# ISM: task:0 sample:290
# ISM: task:0 sample:291
# ISM: task:0 sample:292
# ISM: task:0 sample:293
# ISM: task:0 sample:294
# ISM: task:0 sample:295
# ISM: task:0 sample:296
# ISM: task:0 sample:297
# ISM: task:0 sample:298
# ISM: task:0 sample:299
# ISM: task:0 sample:300
# ISM: task:0 sample:301
# ISM: task:0 sample:302
# ISM: task:0 sample:303
# ISM: task:0 sample:304
# ISM: task:0 sample:305
# ISM: task:0 sample:306
# ISM: task:0 sample:307
# ISM: task:0 sample:308
# ISM: task:0 sample:309
# ISM: task:0 sample:310
# ISM: task:0 sample:311
# ISM: task:0 sample:312
# ISM: task:0 sample:313
# ISM: task:0 sample:314
# ISM: task:0 sample:315
# ISM: task:0 sample:316
# ISM: task:0 sample:317
# ISM: task:0 sample:318
# ISM: task:0 sample:319
# ISM: task:0 sample:320
# ISM: task:0 sample:321
# ISM: task:0 sample:322
# ISM: task:0 sample:323
# ISM: task:0 sample:324
# ISM: task:0 sample:325
# ISM: task:0 sample:326
# ISM: task:0 sample:327
# ISM: task:0 sample:328
# ISM: task:0 sample:329
# ISM: task:0 sample:330
# ISM: task:0 sample:331
# ISM: task:0 sample:332
# ISM: task:0 sample:333
# ISM: task:0 sample:334
# ISM: task:0 sample:335
# ISM: task:0 sample:336
# ISM: task:0 sample:337
# ISM: task:0 sample:338
# ISM: task:0 sample:339
# ISM: task:0 sample:340
# ISM: task:0 sample:341
# ISM: task:0 sample:342
# ISM: task:0 sample:343
# ISM: task:0 sample:344
# ISM: task:0 sample:345
# ISM: task:0 sample:346
# ISM: task:0 sample:347
# ISM: task:0 sample:348
# ISM: task:0 sample:349
# ISM: task:0 sample:350
# ISM: task:0 sample:351
# ISM: task:0 sample:352
# ISM: task:0 sample:353
# ISM: task:0 sample:354
# ISM: task:0 sample:355
# ISM: task:0 sample:356
# ISM: task:0 sample:357
# ISM: task:0 sample:358
# ISM: task:0 sample:359
# ISM: task:0 sample:360
# ISM: task:0 sample:361
# ISM: task:0 sample:362
# ISM: task:0 sample:363
# ISM: task:0 sample:364
# ISM: task:0 sample:365
# ISM: task:0 sample:366
# ISM: task:0 sample:367
# ISM: task:0 sample:368
# ISM: task:0 sample:369
# ISM: task:0 sample:370
# ISM: task:0 sample:371
# ISM: task:0 sample:372
# ISM: task:0 sample:373
# ISM: task:0 sample:374
# ISM: task:0 sample:375
# ISM: task:0 sample:376
# ISM: task:0 sample:377
# ISM: task:0 sample:378
# ISM: task:0 sample:379
# ISM: task:0 sample:380
# ISM: task:0 sample:381
# ISM: task:0 sample:382
# ISM: task:0 sample:383
# ISM: task:0 sample:384
# ISM: task:0 sample:385
# ISM: task:0 sample:386
# ISM: task:0 sample:387
# ISM: task:0 sample:388
# ISM: task:0 sample:389
# ISM: task:0 sample:390
# ISM: task:0 sample:391
# ISM: task:0 sample:392
# ISM: task:0 sample:393
# ISM: task:0 sample:394
# ISM: task:0 sample:395
# ISM: task:0 sample:396
# ISM: task:0 sample:397
# ISM: task:0 sample:398
# ISM: task:0 sample:399
# ISM: task:0 sample:400
# ISM: task:0 sample:401
# ISM: task:0 sample:402
# ISM: task:0 sample:403
# ISM: task:0 sample:404
# ISM: task:0 sample:405
# ISM: task:0 sample:406
# ISM: task:0 sample:407
# ISM: task:0 sample:408
# ISM: task:0 sample:409
# ISM: task:0 sample:410
# ISM: task:0 sample:411
# ISM: task:0 sample:412
# ISM: task:0 sample:413
# ISM: task:0 sample:414
# ISM: task:0 sample:415
# ISM: task:0 sample:416
# ISM: task:0 sample:417
# ISM: task:0 sample:418
# ISM: task:0 sample:419
# ISM: task:0 sample:420
# ISM: task:0 sample:421
# ISM: task:0 sample:422
# ISM: task:0 sample:423
# ISM: task:0 sample:424
# ISM: task:0 sample:425
# ISM: task:0 sample:426
# ISM: task:0 sample:427
# ISM: task:0 sample:428
# ISM: task:0 sample:429
# ISM: task:0 sample:430
# ISM: task:0 sample:431
# ISM: task:0 sample:432
# ISM: task:0 sample:433
# ISM: task:0 sample:434
# ISM: task:0 sample:435
# ISM: task:0 sample:436
# ISM: task:0 sample:437
# ISM: task:0 sample:438
# ISM: task:0 sample:439
# ISM: task:0 sample:440
# ISM: task:0 sample:441
# ISM: task:0 sample:442
# ISM: task:0 sample:443
# ISM: task:0 sample:444
# ISM: task:0 sample:445
# ISM: task:0 sample:446
# ISM: task:0 sample:447
# ISM: task:0 sample:448
# ISM: task:0 sample:449
# ISM: task:0 sample:450
# ISM: task:0 sample:451
# ISM: task:0 sample:452
# ISM: task:0 sample:453
# ISM: task:0 sample:454
# ISM: task:0 sample:455
# ISM: task:0 sample:456
# ISM: task:0 sample:457
# ISM: task:0 sample:458
# ISM: task:0 sample:459
# ISM: task:0 sample:460
# ISM: task:0 sample:461
# ISM: task:0 sample:462
# ISM: task:0 sample:463
# ISM: task:0 sample:464
# ISM: task:0 sample:465
# ISM: task:0 sample:466
# ISM: task:0 sample:467
# ISM: task:0 sample:468
# ISM: task:0 sample:469
# ISM: task:0 sample:470
# ISM: task:0 sample:471
# ISM: task:0 sample:472
# ISM: task:0 sample:473
# ISM: task:0 sample:474
# ISM: task:0 sample:475
# ISM: task:0 sample:476
# ISM: task:0 sample:477
# ISM: task:0 sample:478
# ISM: task:0 sample:479
# ISM: task:0 sample:480
# ISM: task:0 sample:481
# ISM: task:0 sample:482
# ISM: task:0 sample:483
# ISM: task:0 sample:484
# ISM: task:0 sample:485
# ISM: task:0 sample:486
# ISM: task:0 sample:487
# ISM: task:0 sample:488
# ISM: task:0 sample:489
# ISM: task:0 sample:490
# ISM: task:0 sample:491
# ISM: task:0 sample:492
# ISM: task:0 sample:493
# ISM: task:0 sample:494
# ISM: task:0 sample:495
# ISM: task:0 sample:496
# ISM: task:0 sample:497
# ISM: task:0 sample:498
# ISM: task:0 sample:499
# ISM: task:0 sample:500
# ISM: task:0 sample:501
# ISM: task:0 sample:502
# ISM: task:0 sample:503
# ISM: task:0 sample:504
# ISM: task:0 sample:505
# ISM: task:0 sample:506
# ISM: task:0 sample:507
# ISM: task:0 sample:508
# ISM: task:0 sample:509
# ISM: task:0 sample:510
# ISM: task:0 sample:511
# ISM: task:0 sample:512
# ISM: task:0 sample:513
# ISM: task:0 sample:514
# ISM: task:0 sample:515
# ISM: task:0 sample:516
# ISM: task:0 sample:517
# ISM: task:0 sample:518
# ISM: task:0 sample:519
# ISM: task:0 sample:520
# ISM: task:0 sample:521
# ISM: task:0 sample:522
# ISM: task:0 sample:523
# ISM: task:0 sample:524
# ISM: task:0 sample:525
# ISM: task:0 sample:526
# ISM: task:0 sample:527
# ISM: task:0 sample:528
# ISM: task:0 sample:529
# ISM: task:0 sample:530
# ISM: task:0 sample:531
# ISM: task:0 sample:532
# ISM: task:0 sample:533
# ISM: task:0 sample:534
# ISM: task:0 sample:535
# ISM: task:0 sample:536
# ISM: task:0 sample:537
# ISM: task:0 sample:538
# ISM: task:0 sample:539
# ISM: task:0 sample:540
# ISM: task:0 sample:541
# ISM: task:0 sample:542
# ISM: task:0 sample:543
# ISM: task:0 sample:544
# ISM: task:0 sample:545
# ISM: task:0 sample:546
# ISM: task:0 sample:547
# ISM: task:0 sample:548
# ISM: task:0 sample:549
# ISM: task:0 sample:550
# ISM: task:0 sample:551
# ISM: task:0 sample:552
# ISM: task:0 sample:553
# ISM: task:0 sample:554
# ISM: task:0 sample:555
# ISM: task:0 sample:556
# ISM: task:0 sample:557
# ISM: task:0 sample:558
# ISM: task:0 sample:559
# ISM: task:0 sample:560
# ISM: task:0 sample:561
# ISM: task:0 sample:562
# ISM: task:0 sample:563
# ISM: task:0 sample:564
# ISM: task:0 sample:565
# ISM: task:0 sample:566
# ISM: task:0 sample:567
# ISM: task:0 sample:568
# ISM: task:0 sample:569
# ISM: task:0 sample:570
# ISM: task:0 sample:571
# ISM: task:0 sample:572
# ISM: task:0 sample:573
# ISM: task:0 sample:574
# ISM: task:0 sample:575
# ISM: task:0 sample:576
# ISM: task:0 sample:577
# ISM: task:0 sample:578
# ISM: task:0 sample:579
# ISM: task:0 sample:580
# ISM: task:0 sample:581
# ISM: task:0 sample:582
# ISM: task:0 sample:583
# ISM: task:0 sample:584
# ISM: task:0 sample:585
# ISM: task:0 sample:586
# ISM: task:0 sample:587
# ISM: task:0 sample:588
# ISM: task:0 sample:589
# ISM: task:0 sample:590
# ISM: task:0 sample:591
# ISM: task:0 sample:592
# ISM: task:0 sample:593
# ISM: task:0 sample:594
# ISM: task:0 sample:595
# ISM: task:0 sample:596
# ISM: task:0 sample:597
# ISM: task:0 sample:598
# ISM: task:0 sample:599
# ISM: task:0 sample:600
# ISM: task:0 sample:601
# ISM: task:0 sample:602
# ISM: task:0 sample:603
# ISM: task:0 sample:604
# ISM: task:0 sample:605
# ISM: task:0 sample:606
# ISM: task:0 sample:607
# ISM: task:0 sample:608
# ISM: task:0 sample:609
# ISM: task:0 sample:610
# ISM: task:0 sample:611
# ISM: task:0 sample:612
# ISM: task:0 sample:613
# ISM: task:0 sample:614
# ISM: task:0 sample:615
# ISM: task:0 sample:616
# ISM: task:0 sample:617
# ISM: task:0 sample:618
# ISM: task:0 sample:619
# ISM: task:0 sample:620
# ISM: task:0 sample:621
# ISM: task:0 sample:622
# ISM: task:0 sample:623
# ISM: task:0 sample:624
# ISM: task:0 sample:625
# ISM: task:0 sample:626
# ISM: task:0 sample:627
# ISM: task:0 sample:628
# ISM: task:0 sample:629
# ISM: task:0 sample:630
# ISM: task:0 sample:631
# ISM: task:0 sample:632
# ISM: task:0 sample:633
# ISM: task:0 sample:634
# ISM: task:0 sample:635
# ISM: task:0 sample:636
# ISM: task:0 sample:637
# ISM: task:0 sample:638
# ISM: task:0 sample:639
# ISM: task:0 sample:640
# ISM: task:0 sample:641
# ISM: task:0 sample:642
# ISM: task:0 sample:643
# ISM: task:0 sample:644
# ISM: task:0 sample:645
# ISM: task:0 sample:646
# ISM: task:0 sample:647
# ISM: task:0 sample:648
# ISM: task:0 sample:649
# ISM: task:0 sample:650
# ISM: task:0 sample:651
# ISM: task:0 sample:652
# ISM: task:0 sample:653
# ISM: task:0 sample:654
# ISM: task:0 sample:655
# ISM: task:0 sample:656
# ISM: task:0 sample:657
# ISM: task:0 sample:658
# ISM: task:0 sample:659
# ISM: task:0 sample:660
# ISM: task:0 sample:661
# ISM: task:0 sample:662
# ISM: task:0 sample:663
# ISM: task:0 sample:664
# ISM: task:0 sample:665
# ISM: task:0 sample:666
# ISM: task:0 sample:667
# ISM: task:0 sample:668
# ISM: task:0 sample:669
# ISM: task:0 sample:670
# ISM: task:0 sample:671
# ISM: task:0 sample:672
# ISM: task:0 sample:673
# ISM: task:0 sample:674
# ISM: task:0 sample:675
# ISM: task:0 sample:676
# ISM: task:0 sample:677
# ISM: task:0 sample:678
# ISM: task:0 sample:679
# ISM: task:0 sample:680
# ISM: task:0 sample:681
# ISM: task:0 sample:682
# ISM: task:0 sample:683
# ISM: task:0 sample:684
# ISM: task:0 sample:685
# ISM: task:0 sample:686
# ISM: task:0 sample:687
# ISM: task:0 sample:688
# ISM: task:0 sample:689
# ISM: task:0 sample:690
# ISM: task:0 sample:691
# ISM: task:0 sample:692
# ISM: task:0 sample:693
# ISM: task:0 sample:694
# ISM: task:0 sample:695
# ISM: task:0 sample:696
# ISM: task:0 sample:697
# ISM: task:0 sample:698
# ISM: task:0 sample:699
# ISM: task:0 sample:700
# ISM: task:0 sample:701
# ISM: task:0 sample:702
# ISM: task:0 sample:703
# ISM: task:0 sample:704
# ISM: task:0 sample:705
# ISM: task:0 sample:706
# ISM: task:0 sample:707
# ISM: task:0 sample:708
# ISM: task:0 sample:709
# ISM: task:0 sample:710
# ISM: task:0 sample:711
# ISM: task:0 sample:712
# ISM: task:0 sample:713
# ISM: task:0 sample:714
# ISM: task:0 sample:715
# ISM: task:0 sample:716
# ISM: task:0 sample:717
# ISM: task:0 sample:718
# ISM: task:0 sample:719
# ISM: task:0 sample:720
# ISM: task:0 sample:721
# ISM: task:0 sample:722
# ISM: task:0 sample:723
# ISM: task:0 sample:724
# ISM: task:0 sample:725
# ISM: task:0 sample:726
# ISM: task:0 sample:727
# ISM: task:0 sample:728
# ISM: task:0 sample:729
# ISM: task:0 sample:730
# ISM: task:0 sample:731
# ISM: task:0 sample:732
# ISM: task:0 sample:733
# ISM: task:0 sample:734
# ISM: task:0 sample:735
# ISM: task:0 sample:736
# ISM: task:0 sample:737
# ISM: task:0 sample:738
# ISM: task:0 sample:739
# ISM: task:0 sample:740
# ISM: task:0 sample:741
# ISM: task:0 sample:742
# ISM: task:0 sample:743
# ISM: task:0 sample:744
# ISM: task:0 sample:745
# ISM: task:0 sample:746
# ISM: task:0 sample:747
# ISM: task:0 sample:748
# ISM: task:0 sample:749
# ISM: task:0 sample:750
# ISM: task:0 sample:751
# ISM: task:0 sample:752
# ISM: task:0 sample:753
# ISM: task:0 sample:754
# ISM: task:0 sample:755
# ISM: task:0 sample:756
# ISM: task:0 sample:757
# ISM: task:0 sample:758
# ISM: task:0 sample:759
# ISM: task:0 sample:760
# ISM: task:0 sample:761
# ISM: task:0 sample:762
# ISM: task:0 sample:763
# ISM: task:0 sample:764
# ISM: task:0 sample:765
# ISM: task:0 sample:766
# ISM: task:0 sample:767
# ISM: task:0 sample:768
# ISM: task:0 sample:769
# ISM: task:0 sample:770
# ISM: task:0 sample:771
# ISM: task:0 sample:772
# ISM: task:0 sample:773
# ISM: task:0 sample:774
# ISM: task:0 sample:775
# ISM: task:0 sample:776
# ISM: task:0 sample:777
# ISM: task:0 sample:778
# ISM: task:0 sample:779
# ISM: task:0 sample:780
# ISM: task:0 sample:781
# ISM: task:0 sample:782
# ISM: task:0 sample:783
# ISM: task:0 sample:784
# ISM: task:0 sample:785
# ISM: task:0 sample:786
# ISM: task:0 sample:787
# ISM: task:0 sample:788
# ISM: task:0 sample:789
# ISM: task:0 sample:790
# ISM: task:0 sample:791
# ISM: task:0 sample:792
# ISM: task:0 sample:793
# ISM: task:0 sample:794
# ISM: task:0 sample:795
# ISM: task:0 sample:796
# ISM: task:0 sample:797
# ISM: task:0 sample:798
# ISM: task:0 sample:799
# ISM: task:0 sample:800
# ISM: task:0 sample:801
# ISM: task:0 sample:802
# ISM: task:0 sample:803
# ISM: task:0 sample:804
# ISM: task:0 sample:805
# ISM: task:0 sample:806
# ISM: task:0 sample:807
# ISM: task:0 sample:808
# ISM: task:0 sample:809
# ISM: task:0 sample:810
# ISM: task:0 sample:811
# ISM: task:0 sample:812
# ISM: task:0 sample:813
# ISM: task:0 sample:814
# ISM: task:0 sample:815
# ISM: task:0 sample:816
# ISM: task:0 sample:817
# ISM: task:0 sample:818
# ISM: task:0 sample:819
# ISM: task:0 sample:820
# ISM: task:0 sample:821
# ISM: task:0 sample:822
# ISM: task:0 sample:823
# ISM: task:0 sample:824
# ISM: task:0 sample:825
# ISM: task:0 sample:826
# ISM: task:0 sample:827
# ISM: task:0 sample:828
# ISM: task:0 sample:829
# ISM: task:0 sample:830
# ISM: task:0 sample:831
# ISM: task:0 sample:832
# ISM: task:0 sample:833
# ISM: task:0 sample:834
# ISM: task:0 sample:835
# ISM: task:0 sample:836
# ISM: task:0 sample:837
# ISM: task:0 sample:838
# ISM: task:0 sample:839
# ISM: task:0 sample:840
# ISM: task:0 sample:841
# ISM: task:0 sample:842
# ISM: task:0 sample:843
# ISM: task:0 sample:844
# ISM: task:0 sample:845
# ISM: task:0 sample:846
# ISM: task:0 sample:847
# ISM: task:0 sample:848
# ISM: task:0 sample:849
# ISM: task:0 sample:850
# ISM: task:0 sample:851
# ISM: task:0 sample:852

# %%
# %matplotlib inline

from deeplift.visualization import viz_sequence
viz_sequence.plot_weights(ism_scores[0][300:650]*onehot[0,0][300:650])

# %%
import deeplift
from deeplift.conversion import kerasapi_conversion as kc

grad_model =\
    kc.convert_model_from_saved_files(
        model_hdf5,
        nonlinear_mxts_mode=deeplift.layers.NonlinearMxtsMode.Gradient)
grad_contribs_func = grad_model.get_target_contribs_func(
                            find_scores_layer_idx=0,
                            target_layer_idx=-1)
# Out:
# nonlinear_mxts_mode is set to: Gradient
# W0709 16:24:35.623578 140647987721984 deprecation_wrapper.py:119] From /users/avanti/anaconda3/lib/python3.7/site-packages/deeplift/layers/pooling.py:296: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# Heads-up: current implementation assumes maxpool layer is followed by a linear transformation (conv/dense layer)
# Heads-up: current implementation assumes maxpool layer is followed by a linear transformation (conv/dense layer)
# Heads-up: current implementation assumes maxpool layer is followed by a linear transformation (conv/dense layer)

# %%
for idx,(sequences,onehot) in enumerate(zip(sequences_sets, onehot_sets)):
    onehot = onehot[:,None,:,:]
    gradtimesinp_scores = np.array(grad_contribs_func(
        task_idx=0,
        input_data_list=[onehot],
        batch_size=200,
        progress_update=1000))
    print(gradtimesinp_scores.shape)
    onehot = np.squeeze(onehot)
    gradtimesinp_scores = np.squeeze(gradtimesinp_scores)
    np.save("grad_scores_"+str(idx)+".npy", gradtimesinp_scores)
# Out:
# No reference provided - using zeros
# Done 0
# Done 1000
# Done 2000
# Done 3000
# Done 4000
# Done 5000
# Done 6000
# Done 7000
# Done 8000
# (8001, 1, 1000, 4)
# No reference provided - using zeros
# Done 0
# Done 1000
# Done 2000
# Done 3000
# Done 4000
# (4652, 1, 1000, 4)
# No reference provided - using zeros
# Done 0
# Done 1000
# Done 2000
# Done 3000
# Done 4000
# Done 5000
# Done 6000
# Done 7000
# Done 8000
# (8001, 1, 1000, 4)
# No reference provided - using zeros
# Done 0
# Done 1000
# Done 2000
# Done 3000
# Done 4000
# Done 5000
# Done 6000
# Done 7000
# Done 8000
# (8001, 1, 1000, 4)
# No reference provided - using zeros
# Done 0
# Done 1000
# Done 2000
# Done 3000
# Done 4000
# Done 5000
# Done 6000
# Done 7000
# Done 8000
# (8001, 1, 1000, 4)
# No reference provided - using zeros
# Done 0
# Done 1000
# Done 2000
# Done 3000
# Done 4000
# Done 5000
# Done 6000
# Done 7000
# Done 8000
# (8001, 1, 1000, 4)

# %%
import deeplift
from deeplift.conversion import kerasapi_conversion as kc
from deeplift.util import get_shuffle_seq_ref_function
from deeplift.dinuc_shuffle import dinuc_shuffle

deeplift_model =\
    kc.convert_model_from_saved_files(
        model_hdf5,
        nonlinear_mxts_mode=deeplift.layers.NonlinearMxtsMode.Rescale)
deeplift_contribs_func = deeplift_model.get_target_contribs_func(
                            find_scores_layer_idx=0,
                            target_layer_idx=-1)
scoring_func = get_shuffle_seq_ref_function(
    #score_computation_function is the original function to compute scores
    score_computation_function=deeplift_contribs_func,
    #shuffle_func is the function that shuffles the sequence
    #technically, given the background of this simulation, randomly_shuffle_seq
    #makes more sense. However, on real data, a dinuc shuffle is advisable due to
    #the strong bias against CG dinucleotides
    shuffle_func=dinuc_shuffle,
    one_hot_func=None)
# Out:
# nonlinear_mxts_mode is set to: Rescale
# Heads-up: current implementation assumes maxpool layer is followed by a linear transformation (conv/dense layer)
# Heads-up: current implementation assumes maxpool layer is followed by a linear transformation (conv/dense layer)
# Heads-up: current implementation assumes maxpool layer is followed by a linear transformation (conv/dense layer)

# %%
for idx,sequences in enumerate(sequences_sets):
    onehot = onehot_func(sequences)
    deeplift_scores = scoring_func(
        task_idx=0,
        input_data_sequences=onehot,
        num_refs_per_seq=10,
        batch_size=200,
        progress_update=1000)
    print(deeplift_scores.shape)
    onehot = np.squeeze(onehot)
    deeplift_scores = np.squeeze(deeplift_scores)
    projected_deeplift = np.sum(deeplift_scores, axis=-1)[:,:,None]*onehot
    print(projected_deeplift.shape)
    np.save("deeplift_scores_"+str(idx)+".npy", projected_deeplift)
# Out:
# 1000 reference seqs generated
# 2000 reference seqs generated
# 3000 reference seqs generated
# 4000 reference seqs generated
# 5000 reference seqs generated
# 6000 reference seqs generated
# 7000 reference seqs generated
# 8000 reference seqs generated
# 9000 reference seqs generated
# 10000 reference seqs generated
# 11000 reference seqs generated
# 12000 reference seqs generated
# 13000 reference seqs generated
# 14000 reference seqs generated
# 15000 reference seqs generated
# 16000 reference seqs generated
# 17000 reference seqs generated
# 18000 reference seqs generated
# 19000 reference seqs generated
# 20000 reference seqs generated
# 21000 reference seqs generated
# 22000 reference seqs generated
# 23000 reference seqs generated
# 24000 reference seqs generated
# 25000 reference seqs generated
# 26000 reference seqs generated
# 27000 reference seqs generated
# 28000 reference seqs generated
# 29000 reference seqs generated
# 30000 reference seqs generated
# 31000 reference seqs generated
# 32000 reference seqs generated
# 33000 reference seqs generated
# 34000 reference seqs generated
# 35000 reference seqs generated
# 36000 reference seqs generated
# 37000 reference seqs generated
# 38000 reference seqs generated
# 39000 reference seqs generated
# 40000 reference seqs generated
# 41000 reference seqs generated
# 42000 reference seqs generated
# 43000 reference seqs generated
# 44000 reference seqs generated
# 45000 reference seqs generated
# 46000 reference seqs generated
# 47000 reference seqs generated
# 48000 reference seqs generated
# 49000 reference seqs generated
# 50000 reference seqs generated
# 51000 reference seqs generated
# 52000 reference seqs generated
# 53000 reference seqs generated
# 54000 reference seqs generated
# 55000 reference seqs generated
# 56000 reference seqs generated
# 57000 reference seqs generated
# 58000 reference seqs generated
# 59000 reference seqs generated
# 60000 reference seqs generated
# 61000 reference seqs generated
# 62000 reference seqs generated
# 63000 reference seqs generated
# 64000 reference seqs generated
# 65000 reference seqs generated
# 66000 reference seqs generated
# 67000 reference seqs generated
# 68000 reference seqs generated
# 69000 reference seqs generated
# 70000 reference seqs generated
# 71000 reference seqs generated
# 72000 reference seqs generated
# 73000 reference seqs generated
# 74000 reference seqs generated
# 75000 reference seqs generated
# 76000 reference seqs generated
# 77000 reference seqs generated
# 78000 reference seqs generated
# 79000 reference seqs generated
# 80000 reference seqs generated
# Done 0
# Done 1000
# Done 2000
# Done 3000
# Done 4000
# Done 5000
# Done 6000
# Done 7000
# Done 8000
# Done 9000
# Done 10000
# Done 11000
# Done 12000
# Done 13000
# Done 14000
# Done 15000
# Done 16000
# Done 17000
# Done 18000
# Done 19000
# Done 20000
# Done 21000
# Done 22000
# Done 23000
# Done 24000
# Done 25000
# Done 26000
# Done 27000
# Done 28000
# Done 29000
# Done 30000
# Done 31000
# Done 32000
# Done 33000
# Done 34000
# Done 35000
# Done 36000
# Done 37000
# Done 38000
# Done 39000
# Done 40000
# Done 41000
# Done 42000
# Done 43000
# Done 44000
# Done 45000
# Done 46000
# Done 47000
# Done 48000
# Done 49000
# Done 50000
# Done 51000
# Done 52000
# Done 53000
# Done 54000
# Done 55000
# Done 56000
# Done 57000
# Done 58000
# Done 59000
# Done 60000
# Done 61000
# Done 62000
# Done 63000
# Done 64000
# Done 65000
# Done 66000
# Done 67000
# Done 68000
# Done 69000
# Done 70000
# Done 71000
# Done 72000
# Done 73000
# Done 74000
# Done 75000
# Done 76000
# Done 77000
# Done 78000
# Done 79000
# Done 80000
# (8001, 1, 1000, 4)
# (8001, 1000, 4)
# 1000 reference seqs generated
# 2000 reference seqs generated
# 3000 reference seqs generated
# 4000 reference seqs generated
# 5000 reference seqs generated
# 6000 reference seqs generated
# 7000 reference seqs generated
# 8000 reference seqs generated
# 9000 reference seqs generated
# 10000 reference seqs generated
# 11000 reference seqs generated
# 12000 reference seqs generated
# 13000 reference seqs generated
# 14000 reference seqs generated
# 15000 reference seqs generated
# 16000 reference seqs generated
# 17000 reference seqs generated
# 18000 reference seqs generated
# 19000 reference seqs generated
# 20000 reference seqs generated
# 21000 reference seqs generated
# 22000 reference seqs generated
# 23000 reference seqs generated
# 24000 reference seqs generated
# 25000 reference seqs generated
# 26000 reference seqs generated
# 27000 reference seqs generated
# 28000 reference seqs generated
# 29000 reference seqs generated
# 30000 reference seqs generated
# 31000 reference seqs generated
# 32000 reference seqs generated
# 33000 reference seqs generated
# 34000 reference seqs generated
# 35000 reference seqs generated
# 36000 reference seqs generated
# 37000 reference seqs generated
# 38000 reference seqs generated
# 39000 reference seqs generated
# 40000 reference seqs generated
# 41000 reference seqs generated
# 42000 reference seqs generated
# 43000 reference seqs generated
# 44000 reference seqs generated
# 45000 reference seqs generated
# 46000 reference seqs generated
# Done 0
# Done 1000
# Done 2000
# Done 3000
# Done 4000
# Done 5000
# Done 6000
# Done 7000
# Done 8000
# Done 9000
# Done 10000
# Done 11000
# Done 12000
# Done 13000
# Done 14000
# Done 15000
# Done 16000
# Done 17000
# Done 18000
# Done 19000
# Done 20000
# Done 21000
# Done 22000
# Done 23000
# Done 24000
# Done 25000
# Done 26000
# Done 27000
# Done 28000
# Done 29000
# Done 30000
# Done 31000
# Done 32000
# Done 33000
# Done 34000
# Done 35000
# Done 36000
# Done 37000
# Done 38000
# Done 39000
# Done 40000
# Done 41000
# Done 42000
# Done 43000
# Done 44000
# Done 45000
# Done 46000
# (4652, 1, 1000, 4)
# (4652, 1000, 4)
# 1000 reference seqs generated
# 2000 reference seqs generated
# 3000 reference seqs generated
# 4000 reference seqs generated
# 5000 reference seqs generated
# 6000 reference seqs generated
# 7000 reference seqs generated
# 8000 reference seqs generated
# 9000 reference seqs generated
# 10000 reference seqs generated
# 11000 reference seqs generated
# 12000 reference seqs generated
# 13000 reference seqs generated
# 14000 reference seqs generated
# 15000 reference seqs generated
# 16000 reference seqs generated
# 17000 reference seqs generated
# 18000 reference seqs generated
# 19000 reference seqs generated
# 20000 reference seqs generated
# 21000 reference seqs generated
# 22000 reference seqs generated
# 23000 reference seqs generated
# 24000 reference seqs generated
# 25000 reference seqs generated
# 26000 reference seqs generated
# 27000 reference seqs generated
# 28000 reference seqs generated
# 29000 reference seqs generated
# 30000 reference seqs generated
# 31000 reference seqs generated
# 32000 reference seqs generated
# 33000 reference seqs generated
# 34000 reference seqs generated
# 35000 reference seqs generated
# 36000 reference seqs generated
# 37000 reference seqs generated
# 38000 reference seqs generated
# 39000 reference seqs generated
# 40000 reference seqs generated
# 41000 reference seqs generated
# 42000 reference seqs generated
# 43000 reference seqs generated
# 44000 reference seqs generated
# 45000 reference seqs generated
# 46000 reference seqs generated
# 47000 reference seqs generated
# 48000 reference seqs generated
# 49000 reference seqs generated
# 50000 reference seqs generated
# 51000 reference seqs generated
# 52000 reference seqs generated
# 53000 reference seqs generated
# 54000 reference seqs generated
# 55000 reference seqs generated
# 56000 reference seqs generated
# 57000 reference seqs generated
# 58000 reference seqs generated
# 59000 reference seqs generated
# 60000 reference seqs generated
# 61000 reference seqs generated
# 62000 reference seqs generated
# 63000 reference seqs generated
# 64000 reference seqs generated
# 65000 reference seqs generated
# 66000 reference seqs generated
# 67000 reference seqs generated
# 68000 reference seqs generated
# 69000 reference seqs generated
# 70000 reference seqs generated
# 71000 reference seqs generated
# 72000 reference seqs generated
# 73000 reference seqs generated
# 74000 reference seqs generated
# 75000 reference seqs generated
# 76000 reference seqs generated
# 77000 reference seqs generated
# 78000 reference seqs generated
# 79000 reference seqs generated
# 80000 reference seqs generated
# Done 0
# Done 1000
# Done 2000
# Done 3000
# Done 4000
# Done 5000
# Done 6000
# Done 7000
# Done 8000
# Done 9000
# Done 10000
# Done 11000
# Done 12000
# Done 13000
# Done 14000
# Done 15000
# Done 16000
# Done 17000
# Done 18000
# Done 19000
# Done 20000
# Done 21000
# Done 22000
# Done 23000
# Done 24000
# Done 25000
# Done 26000
# Done 27000
# Done 28000
# Done 29000
# Done 30000
# Done 31000
# Done 32000
# Done 33000
# Done 34000
# Done 35000
# Done 36000
# Done 37000
# Done 38000
# Done 39000
# Done 40000
# Done 41000
# Done 42000
# Done 43000
# Done 44000
# Done 45000
# Done 46000
# Done 47000
# Done 48000
# Done 49000
# Done 50000
# Done 51000
# Done 52000
# Done 53000
# Done 54000
# Done 55000
# Done 56000
# Done 57000
# Done 58000
# Done 59000
# Done 60000
# Done 61000
# Done 62000
# Done 63000
# Done 64000
# Done 65000
# Done 66000
# Done 67000
# Done 68000
# Done 69000
# Done 70000
# Done 71000
# Done 72000
# Done 73000
# Done 74000
# Done 75000
# Done 76000
# Done 77000
# Done 78000
# Done 79000
# Done 80000
# (8001, 1, 1000, 4)
# (8001, 1000, 4)
# 1000 reference seqs generated
# 2000 reference seqs generated
# 3000 reference seqs generated
# 4000 reference seqs generated
# 5000 reference seqs generated
# 6000 reference seqs generated
# 7000 reference seqs generated
# 8000 reference seqs generated
# 9000 reference seqs generated
# 10000 reference seqs generated
# 11000 reference seqs generated
# 12000 reference seqs generated
# 13000 reference seqs generated
# 14000 reference seqs generated
# 15000 reference seqs generated
# 16000 reference seqs generated
# 17000 reference seqs generated
# 18000 reference seqs generated
# 19000 reference seqs generated
# 20000 reference seqs generated
# 21000 reference seqs generated
# 22000 reference seqs generated
# 23000 reference seqs generated
# 24000 reference seqs generated
# 25000 reference seqs generated
# 26000 reference seqs generated
# 27000 reference seqs generated
# 28000 reference seqs generated
# 29000 reference seqs generated
# 30000 reference seqs generated
# 31000 reference seqs generated
# 32000 reference seqs generated
# 33000 reference seqs generated
# 34000 reference seqs generated
# 35000 reference seqs generated
# 36000 reference seqs generated
# 37000 reference seqs generated
# 38000 reference seqs generated
# 39000 reference seqs generated
# 40000 reference seqs generated
# 41000 reference seqs generated
# 42000 reference seqs generated
# 43000 reference seqs generated
# 44000 reference seqs generated
# 45000 reference seqs generated
# 46000 reference seqs generated
# 47000 reference seqs generated
# 48000 reference seqs generated
# 49000 reference seqs generated
# 50000 reference seqs generated
# 51000 reference seqs generated
# 52000 reference seqs generated
# 53000 reference seqs generated
# 54000 reference seqs generated
# 55000 reference seqs generated
# 56000 reference seqs generated
# 57000 reference seqs generated
# 58000 reference seqs generated
# 59000 reference seqs generated
# 60000 reference seqs generated
# 61000 reference seqs generated
# 62000 reference seqs generated
# 63000 reference seqs generated
# 64000 reference seqs generated
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-13bc175af916> in <module>
#       6         num_refs_per_seq=10,
#       7         batch_size=200,
# ----> 8         progress_update=1000)
#       9     print(deeplift_scores.shape)
#      10     onehot = np.squeeze(onehot)
#
# ~/anaconda3/lib/python3.7/site-packages/deeplift/util.py in compute_scores_with_shuffle_seq_refs(task_idx, input_data_sequences, num_refs_per_seq, batch_size, seed, progress_update)
#     368                     seq=seq.squeeze()
#     369                 to_run_input_data_seqs.append(seq)
# --> 370                 to_run_input_data_refs.append(shuffle_func(seq))
#     371         if one_hot_func is not None:
#     372             if (progress_update is not None):
#
# ~/anaconda3/lib/python3.7/site-packages/deeplift/dinuc_shuffle.py in dinuc_shuffle(s)
#      39     if isinstance(s, str):
#      40         s=s.upper()
# ---> 41     return traverse_edges(s, shuffle_edges(prepare_edges(s)))
#
# ~/anaconda3/lib/python3.7/site-packages/deeplift/dinuc_shuffle.py in traverse_edges(s, edges)
#      27     for i in range(len(s)-1):
#      28         last_char = generated[-1]
# ---> 29         generated.append(edges[tuple(last_char)][edges_queue_pointers[tuple(last_char)]])
#      30         edges_queue_pointers[tuple(last_char)] += 1
#      31     if isinstance(generated[0],str):
#
# KeyboardInterrupt:

# %%
def make_altered_inputs_for_ism(original_onehot):
    altered_inputs = []
    altered_input_posandbase = []
    for pos_idx in range(375,625):
        for base_idx in range(4):
            new_inp = np.array(original_onehot)
            new_inp[pos_idx] = 0.0
            new_inp[pos_idx][base_idx] = 1.0
            altered_inputs.append(new_inp)
            altered_input_posandbase.append((pos_idx, base_idx))
    return altered_inputs, altered_input_posandbase
def do_ism(onehots, prediction_func, make_altered_inputs_func):
    for onehot in onehots:
        altered_inputs, an
